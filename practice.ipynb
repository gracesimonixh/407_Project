# %%
import pandas as pd

# %%
tickers = ['AAPL', 'SPY']

equity_curve = pd.DataFrame(columns=['Date', 'Cash', 'Portfolio_Value'] + tickers)

equity_curve.head()
# Out:
# Empty DataFrame
# Columns: [Date, Cash, Portfolio_Value, AAPL, SPY]
# Index: []
